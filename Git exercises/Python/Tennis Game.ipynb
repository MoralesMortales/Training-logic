# %%
""" /*
 * Escribe un programa que muestre cómo transcurre un juego de tenis y quién lo ha ganado.
 * El programa recibirá una secuencia formada por "P1" (Player 1) o "P2" (Player 2), según quien
 * gane cada punto del juego.
 * 
 * - Las puntuaciones de un juego son "Love" (cero), 15, 30, 40, "Deuce" (empate), ventaja.
 * - Ante la secuencia [P1, P1, P2, P2, P1, P2, P1, P1], el programa mostraría lo siguiente:
 *   15 - Love
 *   30 - Love
 *   30 - 15
 *   30 - 30
 *   40 - 30
 *   Deuce
 *   Ventaja P1
 *   Ha ganado el P1
 * - Si quieres, puedes controlar errores en la entrada de datos.   
 * - Consulta las reglas del juego si tienes dudas sobre el sistema de puntos.   
 */ """
 
print("Welcome to game system (Tennis edition)")

p1 = input("What's the name of player one or their team?")
p2 = input("What's the name of player two or their team?")
counter_P1 = 0
counter_P2 = 0
sum_point = 0
winner = ""
rounds = 0
print("\nStart\n")

while counter_P2 < 40 and counter_P1 < 40:
    winner = str(input("Who won the last point? (P1 - P2)")).upper()
    
    rounds = rounds + 1
    print(f"Round {rounds}")
    
    if(winner == "P1"):
        
        if counter_P1 == 30:
        
            counter_P1 += 10
            
            if counter_P2 == counter_P1:
                print(f"Deuce -- P1 has currently {counter_P1} ----- P2 {counter_P2}")
                
            elif counter_P2 == 0:
                print(f"P1 has currently {counter_P1} ----- P2 has currently LOVE")
            else:      
                print(f"P1 has currently {counter_P1} ----- P2 has currently {counter_P2}")
    
        else:
            counter_P1 += 15
            
            if counter_P2 == counter_P1:
                print(f"Deuce -- P1 has currently {counter_P1} ----- P2 {counter_P2}")
               
            elif counter_P2 == 0:
                print(f"P1 has currently {counter_P1} ----- P2 has currently LOVE")
            else:
                print(f"P1 has currently {counter_P1} ----- P2 {counter_P2}")
                
    elif(winner == "P2"):
        
            
        if counter_P2 == 30:
 
            counter_P2 += 10
            
            if counter_P2 == counter_P1:
                print(f"Deuce -- P1 has currently {counter_P1} ----- P2 {counter_P2}")
        
            elif counter_P1 == 0:
                print(f"P1 has currently LOVE ----- P2 has currently {counter_P2}")
            else:
                print(f"P1 has currently {counter_P1} ----- P2 ==> {counter_P2}")
                
        else:
            counter_P2 += 15
            
            if counter_P2 == counter_P1:
                print(f"Deuce -- P1 has currently {counter_P1} ----- P2 {counter_P2}")
            
            elif counter_P1 == 0:
                print(f"P1 has currently LOVE ----- P2 has currently {counter_P2}")

            else:
                print(f"P1 has currently {counter_P1} ----- P2 {counter_P2}")

          



def DeuceOrTie_funtion(p1, p2):
    
    if p1 == p2:
        print("Ambos equipos estan en Deuce")
# Out:
# Welcome to game system (Tennis edition)
#
# Start
#
# Round 1
# P1 has currently 15 ----- P2 has currently LOVE
# Round 2
# Deuce -- P1 has currently 15 ----- P2 15
# Round 3
# P1 has currently 30 ----- P2 15
# Round 4
# Deuce -- P1 has currently 30 ----- P2 30
# Round 5
# P1 has currently 40 ----- P2 has currently 30
